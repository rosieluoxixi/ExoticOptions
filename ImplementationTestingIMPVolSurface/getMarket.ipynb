# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')
data
# Out:
#    days    domdf    fordf  10dput  25dput  50dcall  25dcall  10dcall
# 0     7  0.99962  0.99923   20.80   20.20     20.0    20.40    21.60
# 1    14  0.99922  0.99845   21.32   20.71     20.5    20.91    22.14
# 2    21  0.99882  0.99766   21.84   21.21     21.0    21.42    22.68
# 3    28  0.99841  0.99685   22.36   21.72     21.5    21.93    23.22
# 4    59  0.99655  0.99322   23.40   22.73     22.5    22.95    24.30
# 5    89  0.99466  0.98959   24.96   24.24     24.0    24.48    25.92
# 6   181  0.98866  0.97818   26.00   25.25     25.0    25.50    27.00
# 7   365  0.97579  0.95432   27.04   26.26     26.0    26.52    28.08
# 8   546  0.96138  0.92864   29.12   28.28     28.0    28.56    30.24
# 9   730  0.94457  0.89984   31.20   30.30     30.0    30.60    32.40

# %%
days, domdf, fordf = data['days'], data['domdf'], data['fordf']
vols = data[['10dput', '25dput', '50dcall', '25dcall', '10dcall']] / 100

# %%
cps = [-1, -1, 1, 1, 1]
deltas = [0.1, 0.25, 0.5, 0.25, 0.1]
spot = 1.5123
tau = 2

# %%
vols
# Out:
#    10dput  25dput  50dcall  25dcall  10dcall
# 0  0.2080  0.2020    0.200   0.2040   0.2160
# 1  0.2132  0.2071    0.205   0.2091   0.2214
# 2  0.2184  0.2121    0.210   0.2142   0.2268
# 3  0.2236  0.2172    0.215   0.2193   0.2322
# 4  0.2340  0.2273    0.225   0.2295   0.2430
# 5  0.2496  0.2424    0.240   0.2448   0.2592
# 6  0.2600  0.2525    0.250   0.2550   0.2700
# 7  0.2704  0.2626    0.260   0.2652   0.2808
# 8  0.2912  0.2828    0.280   0.2856   0.3024
# 9  0.3120  0.3030    0.300   0.3060   0.3240

# %%
days
# Out:
# 0      7
# 1     14
# 2     21
# 3     28
# 4     59
# 5     89
# 6    181
# 7    365
# 8    546
# 9    730
# Name: days, dtype: int64
